# %% [markdown]
# ---
# layout: post
# current: post
# cover:  assets/built/images/chan_dev_history.png
# navigation: True
# title: 자기 개발 기록 (2023년2월)
# date: 2023-04-22 00:00:00 +0900
# tags: [Chan_dev_history]
# class: post-template
# subclass: 'post tag-python'
# author: chanp5660
# ---

# %% [markdown]
# # 자기 개발 기록 (2023년 2월)
#
# ## 목적
#
# > 자기 개발 기록을 통해 성과, 반성, 배울 점을 얻고 성장할 수 있도록 합니다.
#
# ## 1주차 2023년 1월 31일
#
# > 스터디(카페), Supervised Learning with scikit-learn, 머신러닝 워크플로우, 깃허브 블로그 업로드 자동화
#
# <details>
# <summary><span style="color:blue;font-weight:bold" >여기를 클릭하여 펼치기...</span></summary>
# <div markdown="1">
# - 스터디
#     - 취업 준비를 위한 이력서, 면접, 공부를 위한 스터디를 당근에서 같이 스터디 할 사람을 구해서 카페에서 공부를 했습니다.
# - Supervised Learning with scikit-learn
#     - 데이터캠프 - Machine Learning Scientist with Python
#     - 1년동안 잊어버려 다시 공부하면서 공부 흐름을 찾는 데 쉽지 않았습니다. 특히 영어…
#     - Clustering for Dataset Exploration
#     - Visualization with Hierarchical Clustering and t-SNE
#     - Decorrelating Your Data and Dimension Reduction
#     - Discovering Interpretable Feature
# - 머신러닝 워크플로우(블로그포스팅)
#     - 자연어처리입문
# - 깃허브 블로그 업로드 자동화
#      - 기존에 해놓은 자동화는 본체에서 했었는데 노트북으로 전체 과정을 옮기면서 노트북에서 ipynb을 블로그에 포스팅 할 수 있도록 해놓았습니다.
#
# ---
# </div>
# </details>
#
# ## 2주차 2023년 2월 6일
#
# > 이력 신청 가능 회사, 서포트 벡터 머신, 머신러닝 엔지니어 자격요건, 내적연산, 유클리드 공간, Unsupervised Learning in Python
#
# <details>
# <summary><span style="color:blue;font-weight:bold" >여기를 클릭하여 펼치기...</span></summary>
# <div markdown="1">
# - 이력 신청 가능 회사에 대해 공부를 하면서 요즘 어떤 회사들이 있고 어떤 아이템들이 존재하고 위치는 어디쪽에 모여있는 등의 회사 정보들을 얻었습니다.(블로그포스팅)
#     - RIDI, 에이아이스페라, 데이터비, 애크미랩, 이노룰스, 한국해양기상기술, 코난테크놀로지
# - 서포트 벡터 머신(블로그포스팅)
# - 머신러닝 엔지니어 자격요건
#     - 채용공고를 보면서 어떤 자격을 요구하는지 정리했습니다.
# - 내적연산(블로그포스팅)
# - 유클리드공간(블로그포스팅)
# - Unsupervised Learning with python
#     - 데이터캠프 - Machine Learning Scientist with Python
#     - Classification
#     - Regression
#     - Fine-Tuning Your Model
#     - Preprocessing and Pipelines
#
# ---
# </div>
# </details>
#
# ## 3주차 2023년 2월 13일
# > 이력 신청 가능 회사, 로지스틱회귀, 결정경계, 선형분류, 손실함수, Linear Classifier in Python
#
# <details>
# <summary><span style="color:blue;font-weight:bold" >여기를 클릭하여 펼치기...</span></summary>
# <div markdown="1">
# - 이력 신청 가능 회사에 대해 공부를 하면서 요즘 어떤 회사들이 있고 어떤 아이템들이 존재하고 위치는 어디쪽에 모여있는 등의 회사 정보들을 얻었습니다.(블로그포스팅)
#     - 비즈데이터, 인사이저, 아크릴, 노리스페이스, 마키나락스
# - 로지스틱회귀(블로그포스팅)
# - 결정경계(블로그포스팅)
# - 선형분류(블로그포스팅)
# - 손실함수(블로그포스팅)
# - Linear Classifier in Python
#     - 데이터캠프
#     - Machine Learning Scientist with Python
#     - Applying logistic regression and SVM
#     - Loss functions
#     - Logistic regression
#     - Support Vector Machines
#
# ---
# </div>
# </details>
#
# ## 4주차 2023년 2월 20일
# > 이력 신청 가능 회사, 비지도학습, 지도학습, 의사결정트리, Machine Learning with Tree-Based Models in Python
#
# <details>
# <summary><span style="color:blue;font-weight:bold" >여기를 클릭하여 펼치기...</span></summary>
# <div markdown="1">
# - 이력 신청 가능 회사에 대해 공부를 하면서 요즘 어떤 회사들이 있고 어떤 아이템들이 존재하고 위치는 어디쪽에 모여있는 등의 회사 정보들을 얻었습니다. (블로그포스팅)
#     - 액션파워, 엔텔스, 웨인힐스벤처스
# - 비지도학습(블로그포스팅)
# - 의사결정트리(블로그포스팅)
# - Machine Learning with Tree-Based Models in Python
#     - 데이터캠프 - Machine Learning Scientist with Python
#     - Classification and Regression Trees
#     - The Bias-Variance Treadeoff
#     - Bagging and Random Forests
#     - Boosting
#     - Model Tuning
#
# ---
# </div>
# </details>
